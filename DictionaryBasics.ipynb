# %% [markdown]
# <a href="https://colab.research.google.com/github/mahnajbintarahman/Data_Analytics/blob/main/DictionaryBasics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# dictionary
d = {
    1:'mahnaj',
    2:'Binta',
    3:'Rahman',

}
print(d.get(1))
print(d[2])
d[4]= 'Mahin'
print(d)
Remove = d.pop(4)
print(Remove)
print(d)
print(d.keys())
print(d.values())
print(d.items())
print(len(d))
print(d.get(5,'Not found'))
print(d.copy())
print(d.clear())
# Out:
# mahnaj
# Binta
# {1: 'mahnaj', 2: 'Binta', 3: 'Rahman', 4: 'Mahin'}
# Mahin
# {1: 'mahnaj', 2: 'Binta', 3: 'Rahman'}
# dict_keys([1, 2, 3])
# dict_values(['mahnaj', 'Binta', 'Rahman'])
# dict_items([(1, 'mahnaj'), (2, 'Binta'), (3, 'Rahman')])
# 3
# Not found
# {1: 'mahnaj', 2: 'Binta', 3: 'Rahman'}
# None
